# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffersonRodrigues9/Projetos-em-Machine-Learning/blob/main/Rede_neural_Artificial_e_Learning_limite_credito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REDE NEURAL ARTIFICIAL E DEEP LEARNING LIMITE DE CREDITO**

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. Carregar os Dados
df = pd.read_csv('limites_de_credito.csv')
X = df[['Idade', 'Salario', 'Score_Credito']]
y = df['Limite_Aprovado']

# 2. Normalizar X (Entradas) e também y (Alvo)
normalizador_x = StandardScaler()
X_norm = normalizador_x.fit_transform(X)

normalizador_y = StandardScaler()
y_norm = normalizador_y.fit_transform(y.values.reshape(-1,1))

# Passar as variáveis normalizadas para o treino
X_treino, X_teste, y_treino, y_teste = train_test_split(X_norm, y_norm, test_size=0.2, random_state=42)

# Contruindo a IA
modelo_limite = keras.Sequential([
    keras.Input(shape=(3,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(1)
])

modelo_limite.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Treinar o modelo
print("Treinar o avaliador de limites ...")
# Vamos aumentar para 100 épocas para ter melhor precisão
modelo_limite.fit(X_treino, y_treino, epochs=100)
print("Treino Concluído!\n")

# 5. Testando com o nosso cliente real
# Cliente tem 35 anos, ganha $ 8.000 e tem Score de 750
cliente_novo = pd.DataFrame({'Idade': [35], 'Salario': [8000], 'Score_Credito':[750]})
cliente_norm = normalizador_x.transform(cliente_novo)

# A IA vai prever um número pequeno (ex:0.15)
limite_previsto_norm = modelo_limite.predict(cliente_norm)

# Usamos o normalizador para reverter o número para reais
limite_real = normalizador_y.inverse_transform(limite_previsto_norm)

print(f"O Limite de crédito sugerido pela IA é: R$ {limite_real[0][0]:.2f}")
# Out:
# Treinar o avaliador de limites ...
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.0930 - mae: 0.8647
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0081 - mae: 0.8326
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9369 - mae: 0.8036
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8631 - mae: 0.7736
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8023 - mae: 0.7460
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7420 - mae: 0.7177
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6902 - mae: 0.6913
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6368 - mae: 0.6647
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5938 - mae: 0.6403
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5492 - mae: 0.6140
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5117 - mae: 0.5901
# Epoch 12/100
# ...
