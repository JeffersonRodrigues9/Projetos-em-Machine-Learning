# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffersonRodrigues9/Projetos-em-Machine-Learning/blob/main/Chat_bot_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import openai

# Configuração da chave do OpenRouter
CHAVE_API = userdata.get('OPENROUTER_API_KEY')

client = openai.OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=CHAVE_API
)

# Defenir o modelo a ser utilizado
MODELO = "meta-llama/llama-3.1-8b-instruct"

while True:
    pergunta = input("\nPergunta: ")
    if pergunta.lower() in ['sair', 'exit']:
        break

    resposta = client.chat.completions.create(
        model=MODELO,
        messages=[
            {"role": "user", "content": pergunta}
        ]
    )

    print(resposta.choices[0].message.content)
# Out:
# Pergunta: capital do brasil
# A capital do Brasil é Brasília! Ela foi inaugurada em 21 de abril de 1960, substituindo Rio de Janeiro como a capital do país. Brasília é conhecida por sua arquitetura inovadora e planejamento urbano único, projetado pelo famoso arquiteto Oscar Niemeyer e pelo urbanista Lúcio Costa.
#
# Alguns dos principais pontos turísticos de Brasília incluem:
#
# *   **Catedral Metropolitana**: Uma das marcas registradas da cidade, a catedral é uma obra-prima de arquitetura religiosa e é uma das maiores do mundo.
# *   **Palácio do Planalto**: O palácio que serve como sede do Governo Federal.
# *   **Itamaraty**: O Ministério das Relações Exteriores.
# *   **Parque Nacional da Chapada das Mesas**: Um parque nacional localizado na periferia da cidade, com paisagens naturais impressionantes.
# *   **Córrego do Bosque**: Uma área verde na qual se localiza um pouco do mais importante parque da cidade.
